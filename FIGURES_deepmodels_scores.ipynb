# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_multiSubject_binary = pd.read_csv('experiments/experiment2/results/deep_data/multiSubject_binary.csv')
df_multiSubject_binaryCV = pd.read_csv('experiments/experiment2/results/deep_data/multiSubject_binaryCV.csv')
df_multiSubject_multiclass = pd.read_csv('experiments/experiment2/results/deep_data/multiSubject_multiclass.csv')
df_multiSubject_multiclassCV = pd.read_csv('experiments/experiment2/results/deep_data/multiSubject_multiclassCV.csv')
df_finetuning_multiclass = pd.read_csv('experiments/experiment2/results/deep_data/finetuning_multiclass.csv')
df_finetuning_binary = pd.read_csv('experiments/experiment2/results/deep_data/finetuning_binary.csv')

interest_condition = "WindowDuration"

# %%
df_binary = df_multiSubject_binary
df_discrete = df_multiSubject_multiclass

#melt
df_long_binary = pd.melt(df_binary.reset_index(), id_vars=[interest_condition, 'Classifier'], value_vars=['Macro F1'], 
                         var_name='Metric', value_name='F1 Score')
df_long_discrete = pd.melt(df_discrete.reset_index(), id_vars=[interest_condition, 'Classifier'], value_vars=['Macro F1'], 
                           var_name='Metric', value_name='F1 Score')
palette = ["#33658a", "#758e4f", "#f6ae2d", "#f26419", "#b4436c"]
palette2 = ["#93b5c6", "#ddedaa", "#f0cf65", "#d7816a", "#bd4f6c"]


fig, axes = plt.subplots(2, 1, figsize=(24, 15), sharex=True)

sns.barplot(data=df_long_binary, x=interest_condition, y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
axes[0].axhline(y=0.5, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[0].set_title('Binary Classfiers', fontsize=37)
axes[0].set_xlabel('Condition', fontsize=32)
axes[0].set_ylabel('F1 Score', fontsize=32)
axes[0].tick_params(axis='x', rotation=20, labelsize=30)
axes[0].tick_params(axis='y', labelsize=30)
axes[0].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

sns.barplot(data=df_long_discrete, x=interest_condition, y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])
axes[1].axhline(y=0.33, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[1].set_title('Discrete Classifiers', fontsize=35)
axes[1].set_xlabel('Condition', fontsize=30)
axes[1].set_ylabel('F1 Score', fontsize=30)
axes[1].tick_params(axis='x', rotation=20, labelsize=28)
axes[1].tick_params(axis='y', labelsize=28)
axes[1].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/4187912764.py:15: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_binary, x=interest_condition, y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/4187912764.py:24: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_discrete, x=interest_condition, y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])

# %%
df_binary = df_multiSubject_binaryCV
df_discrete = df_multiSubject_multiclassCV

#melt
df_long_binary = pd.melt(df_binary.reset_index(), id_vars=[interest_condition, 'Classifier'], value_vars=['Macro F1'], 
                         var_name='Metric', value_name='F1 Score')
df_long_discrete = pd.melt(df_discrete.reset_index(), id_vars=[interest_condition, 'Classifier'], value_vars=['Macro F1'], 
                           var_name='Metric', value_name='F1 Score')
palette = ["#33658a", "#758e4f", "#f6ae2d", "#f26419", "#b4436c"]
palette2 = ["#93b5c6", "#ddedaa", "#f0cf65", "#d7816a", "#bd4f6c"]


fig, axes = plt.subplots(2, 1, figsize=(24, 15), sharex=True)

sns.barplot(data=df_long_binary, x=interest_condition, y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
axes[0].axhline(y=0.5, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[0].set_title('Binary Classfiers', fontsize=37)
axes[0].set_xlabel('Condition', fontsize=32)
axes[0].set_ylabel('F1 Score', fontsize=32)
axes[0].tick_params(axis='x', rotation=20, labelsize=30)
axes[0].tick_params(axis='y', labelsize=30)
axes[0].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

sns.barplot(data=df_long_discrete, x=interest_condition, y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])
axes[1].axhline(y=0.33, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[1].set_title('Discrete Classifiers', fontsize=35)
axes[1].set_xlabel('Condition', fontsize=30)
axes[1].set_ylabel('F1 Score', fontsize=30)
axes[1].tick_params(axis='x', rotation=20, labelsize=28)
axes[1].tick_params(axis='y', labelsize=28)
axes[1].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/198168340.py:15: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_binary, x=interest_condition, y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/198168340.py:24: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_discrete, x=interest_condition, y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])

# %%
df_binary = df_multiSubject_binary
df_discrete = df_multiSubject_multiclass

#melt
df_long_binary = pd.melt(df_binary.reset_index(), id_vars=['TrainConditions', 'Classifier'], value_vars=['Macro F1'], 
                         var_name='Metric', value_name='F1 Score')
df_long_discrete = pd.melt(df_discrete.reset_index(), id_vars=['TrainConditions', 'Classifier'], value_vars=['Macro F1'], 
                           var_name='Metric', value_name='F1 Score')
palette = ["#33658a", "#758e4f", "#f6ae2d", "#f26419", "#b4436c"]
palette2 = ["#93b5c6", "#ddedaa", "#f0cf65", "#d7816a", "#bd4f6c"]


fig, axes = plt.subplots(2, 1, figsize=(24, 15), sharex=True)

sns.barplot(data=df_long_binary, x='TrainConditions', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
axes[0].axhline(y=0.5, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[0].set_title('Binary Classfiers', fontsize=37)
axes[0].set_xlabel('Condition', fontsize=32)
axes[0].set_ylabel('F1 Score', fontsize=32)
axes[0].tick_params(axis='x', rotation=20, labelsize=30)
axes[0].tick_params(axis='y', labelsize=30)
axes[0].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

sns.barplot(data=df_long_discrete, x='TrainConditions', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])
axes[1].axhline(y=0.33, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[1].set_title('Discrete Classifiers', fontsize=35)
axes[1].set_xlabel('Condition', fontsize=30)
axes[1].set_ylabel('F1 Score', fontsize=30)
axes[1].tick_params(axis='x', rotation=20, labelsize=28)
axes[1].tick_params(axis='y', labelsize=28)
axes[1].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/4132330637.py:15: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_binary, x='TrainConditions', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/4132330637.py:24: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_discrete, x='TrainConditions', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])

# %%
df_binary = df_multiSubject_binary
df_discrete = df_multiSubject_multiclass

#melt
df_long_binary = pd.melt(df_binary.reset_index(), id_vars=['WindowStepSize', 'Classifier'], value_vars=['Macro F1'], 
                         var_name='Metric', value_name='F1 Score')
df_long_discrete = pd.melt(df_discrete.reset_index(), id_vars=['WindowStepSize', 'Classifier'], value_vars=['Macro F1'], 
                           var_name='Metric', value_name='F1 Score')
palette = ["#33658a", "#758e4f", "#f6ae2d", "#f26419", "#b4436c"]
palette2 = ["#93b5c6", "#ddedaa", "#f0cf65", "#d7816a", "#bd4f6c"]


fig, axes = plt.subplots(2, 1, figsize=(24, 15), sharex=True)

sns.barplot(data=df_long_binary, x='WindowStepSize', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
axes[0].axhline(y=0.5, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[0].set_title('Binary Classfiers', fontsize=37)
axes[0].set_xlabel('Condition', fontsize=32)
axes[0].set_ylabel('F1 Score', fontsize=32)
axes[0].tick_params(axis='x', rotation=20, labelsize=30)
axes[0].tick_params(axis='y', labelsize=30)
axes[0].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

sns.barplot(data=df_long_discrete, x='WindowStepSize', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])
axes[1].axhline(y=0.33, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[1].set_title('Discrete Classifiers', fontsize=35)
axes[1].set_xlabel('Condition', fontsize=30)
axes[1].set_ylabel('F1 Score', fontsize=30)
axes[1].tick_params(axis='x', rotation=20, labelsize=28)
axes[1].tick_params(axis='y', labelsize=28)
axes[1].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/3651429330.py:15: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_binary, x='WindowStepSize', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/3651429330.py:24: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_discrete, x='WindowStepSize', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])

# %%
df_binary = df_multiSubject_binaryCV
df_discrete = df_multiSubject_multiclassCV

#melt
df_long_binary = pd.melt(df_binary.reset_index(), id_vars=['WindowStepSize', 'Classifier'], value_vars=['Macro F1'], 
                         var_name='Metric', value_name='F1 Score')
df_long_discrete = pd.melt(df_discrete.reset_index(), id_vars=['WindowStepSize', 'Classifier'], value_vars=['Macro F1'], 
                           var_name='Metric', value_name='F1 Score')
palette = ["#33658a", "#758e4f", "#f6ae2d", "#f26419", "#b4436c"]
palette2 = ["#93b5c6", "#ddedaa", "#f0cf65", "#d7816a", "#bd4f6c"]


fig, axes = plt.subplots(2, 1, figsize=(24, 15), sharex=True)

sns.barplot(data=df_long_binary, x='WindowStepSize', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
axes[0].axhline(y=0.5, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[0].set_title('Binary Classfiers', fontsize=37)
axes[0].set_xlabel('Condition', fontsize=32)
axes[0].set_ylabel('F1 Score', fontsize=32)
axes[0].tick_params(axis='x', rotation=20, labelsize=30)
axes[0].tick_params(axis='y', labelsize=30)
axes[0].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

sns.barplot(data=df_long_discrete, x='WindowStepSize', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])
axes[1].axhline(y=0.33, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[1].set_title('Discrete Classifiers', fontsize=35)
axes[1].set_xlabel('Condition', fontsize=30)
axes[1].set_ylabel('F1 Score', fontsize=30)
axes[1].tick_params(axis='x', rotation=20, labelsize=28)
axes[1].tick_params(axis='y', labelsize=28)
axes[1].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/223756715.py:15: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_binary, x='WindowStepSize', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/223756715.py:24: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_discrete, x='WindowStepSize', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])

# %%
df_binary = df_multiSubject_binaryCV
df_discrete = df_multiSubject_multiclassCV

#melt
df_long_binary = pd.melt(df_binary.reset_index(), id_vars=['TestParticipants', 'Classifier'], value_vars=['Macro F1'], 
                         var_name='Metric', value_name='F1 Score')
df_long_discrete = pd.melt(df_discrete.reset_index(), id_vars=['TestParticipants', 'Classifier'], value_vars=['Macro F1'], 
                           var_name='Metric', value_name='F1 Score')
palette = ["#33658a", "#758e4f", "#f6ae2d", "#f26419", "#b4436c"]
palette2 = ["#93b5c6", "#ddedaa", "#f0cf65", "#d7816a", "#bd4f6c"]


fig, axes = plt.subplots(2, 1, figsize=(24, 15), sharex=True)

sns.barplot(data=df_long_binary, x='TestParticipants', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
axes[0].axhline(y=0.5, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[0].set_title('Binary Classfiers', fontsize=37)
axes[0].set_xlabel('Condition', fontsize=32)
axes[0].set_ylabel('F1 Score', fontsize=32)
axes[0].tick_params(axis='x', rotation=20, labelsize=30)
axes[0].tick_params(axis='y', labelsize=30)
axes[0].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

sns.barplot(data=df_long_discrete, x='TestParticipants', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])
axes[1].axhline(y=0.33, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[1].set_title('Discrete Classifiers', fontsize=35)
axes[1].set_xlabel('Condition', fontsize=30)
axes[1].set_ylabel('F1 Score', fontsize=30)
axes[1].tick_params(axis='x', rotation=20, labelsize=28)
axes[1].tick_params(axis='y', labelsize=28)
axes[1].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/1572387873.py:15: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_binary, x='TestParticipants', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/1572387873.py:24: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_discrete, x='TestParticipants', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])

# %%
df_binary = df_finetuning_binary
df_discrete = df_finetuning_multiclass

#melt
df_long_binary = pd.melt(df_binary.reset_index(), id_vars=['TestParticipants', 'Classifier'], value_vars=['Macro F1'], 
                         var_name='Metric', value_name='F1 Score')
df_long_discrete = pd.melt(df_discrete.reset_index(), id_vars=['TestParticipants', 'Classifier'], value_vars=['Macro F1'], 
                           var_name='Metric', value_name='F1 Score')
palette = ["#33658a", "#758e4f", "#f6ae2d", "#f26419", "#b4436c"]
palette2 = ["#93b5c6", "#ddedaa", "#f0cf65", "#d7816a", "#bd4f6c"]


fig, axes = plt.subplots(2, 1, figsize=(24, 15), sharex=True)

sns.barplot(data=df_long_binary, x='TestParticipants', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
axes[0].axhline(y=0.5, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[0].set_title('Binary Classfiers', fontsize=37)
axes[0].set_xlabel('Condition', fontsize=32)
axes[0].set_ylabel('F1 Score', fontsize=32)
axes[0].tick_params(axis='x', rotation=20, labelsize=30)
axes[0].tick_params(axis='y', labelsize=30)
axes[0].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

sns.barplot(data=df_long_discrete, x='TestParticipants', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])
axes[1].axhline(y=0.33, color='r', linestyle='--', linewidth=1, label='Random Chance')
axes[1].set_title('Discrete Classifiers', fontsize=35)
axes[1].set_xlabel('Condition', fontsize=30)
axes[1].set_ylabel('F1 Score', fontsize=30)
axes[1].tick_params(axis='x', rotation=20, labelsize=28)
axes[1].tick_params(axis='y', labelsize=28)
axes[1].legend(title='Classifier', title_fontsize='28', fontsize='26', loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/1780084435.py:15: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_binary, x='TestParticipants', y='F1 Score', hue='Classifier', palette=palette, ax=axes[0])
# /var/folders/qk/pvrkjyq14k50rmvbny7qk29w0000gn/T/ipykernel_16457/1780084435.py:24: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.barplot(data=df_long_discrete, x='TestParticipants', y='F1 Score', hue='Classifier', palette=palette2, ax=axes[1])
